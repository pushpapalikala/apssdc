# %% [markdown]
# # flavors data set's

# %% [markdown]
# ## 1.Get the data

# %%
flavors=pd.read_csv("flavors.csv")
flavors.head(50)
# Out:
#           celery   vegetable
# 0           corn   vegetable
# 1       cucumber   vegetable
# 2    horseradish   vegetable
# 3      vegetable   vegetable
# 4         potato   vegetable
# 5         tomato   vegetable
# 6        caraway  herbaceous
# 7          clove  herbaceous
# 8         fennel  herbaceous
# 9     herbaceous  herbaceous
# 10          sage  herbaceous
# 11        butter       fatty
# 12        cheese       fatty
# 13        creamy       fatty
# 14       hop_oil       fatty
# 15          oily       fatty
# 16         fatty       fatty
# 17          sour       fatty
# 18      coumarin       spicy
# 19         spicy       spicy
# 20       blossom      floral
# 21     carnation      floral
# 22      gardenia      floral
# 23      geranium      floral
# 24     hawthorne      floral
# 25      hyacinth      floral
# 26          iris      floral
# 27       jasmine      floral
# 28      lavender      floral
# 29          lily      floral
# 30      marigold      floral
# ...

# %% [markdown]
# ## 2.Clean and manipulate the data

# %%
flavors.dropna(inplace=True)
flavors.isnull().sum()
# Out:
# celery       0
# vegetable    0
# dtype: int64

# %% [markdown]
# ## 3.Train the model and testing the model

# %%
from sklearn.linear_model import LinearRegression

# %%
x = flavors.drop('celery',axis =1)
y = flavors['celery']

# %%
from  sklearn.preprocessing import LabelEncoder

lbc = LabelEncoder()
flavors['celery']=lbc.fit_transform(f['celery'])
flavors['vegetable']=lbc.fit_transform(f['vegetable']
flavors.head()
# Out:
#   File "<ipython-input-7-3c4cf330aabb>", line 6
#     flavors.head()
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 4.Accuracy score or c2 score
